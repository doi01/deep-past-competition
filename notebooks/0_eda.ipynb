# %% [markdown]
# EDA
# 1. train.csv — основной (обучающая выборка)
# 2. published_texts.csv — расширение параллельных данных (можно извлечь дополнительные пары)
# 3. Sentences_Oare_FirstWord_LinNum.csv — выравненные предложения/метаданные для токен‑уровневой разметки
# 4. OA_Lexicon_eBL.csv, eBL_Dictionary.csv — лексиконы и определения для фич/копирования/словесного словаря 🔧
# 5. test.csv, sample_submission.csv — формат оценки и тестирования
# 6. resources.csv, bibliography.csv, publications.csv — полезны для доменной адаптации и дополнительного контекста, но не как прямые обучающие пары
#
# Модели:
# google/byt5-small - работает на байтах (char-level) → почти не страдает от OOV + можно апгрейд до google/byt5-base
#
# После разбиения train на предложения можно:
# - более умный alignment (embeddings, cosine similarity)
# - partial alignment
# - confidence-based filtering

# %%
import pandas as pd

train_raw = pd.read_csv('../data/raw/train.csv')

train_raw
# Out:
#                                    oare_id  \
# 0     004a7dbd-57ce-46f8-9691-409be61c676e
# 1     0064939c-59b9-4448-a63d-34612af0a1b5
# 2     0073f2c0-524c-4bbf-915a-8c1772a4fb98
# 3     009fb838-8038-42bc-ad34-5f795b3840ee
# 4     00aa1c55-c80c-4346-a159-73ad43ab0ff7
# ...                                    ...
# 1556  ff3208e4-8ab8-4368-b4df-7b80afa5bc32
# 1557  ff43a284-3d67-4238-8b4a-9b6cb7531e0a
# 1558  ff5747a4-af8a-4100-a906-a2660ae72606
# 1559  ff777871-97ce-4bfc-bdfb-73352868944d
# 1560  ff9442fd-9e7d-449c-a2d6-0cc35921cd65
#
#                                         transliteration  \
# 0     KIŠIB ma-nu-ba-lúm-a-šur DUMU ṣí-lá-(d)IM KIŠI...
# 1                  1 TÚG ša qá-tim i-tur₄-DINGIR il₅-qé
# 2     TÚG u-la i-dí-na-ku-um i-tù-ra-ma 9 GÍN KÙ.BABBAR
# 3     KIŠIB šu-(d)EN.LÍL DUMU šu-ku-bi-im KIŠIB ṣí-l...
# 4     um-ma šu-ku-tum-ma a-na IŠTAR-lá-ma-sí ù ni-ta...
# ...                                                 ...
# ...
